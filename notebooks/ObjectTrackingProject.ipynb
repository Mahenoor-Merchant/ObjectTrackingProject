# %% [markdown]
# # Object Tracking through Yolov5 and Deepsort

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
# %cd /content/drive/MyDrive/DataScience/ComputerVision
# Out:
# Running cells with 'Deepsortvenv (Python 3.7.16)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n Deepsortvenv ipykernel --update-deps --force-reinstall'

# %%
# !git clone https://github.com/ultralytics/yolov5

# %pip install -qr yolov5/requirements.txt  # install dependencies
# Out:
# Running cells with 'Deepsortvenv (Python 3.7.16)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n Deepsortvenv ipykernel --update-deps --force-reinstall'

# %%
# !git clone https://github.com/gongliyu/Yolov5_DeepSort_Pytorch
# Out:
# Cloning into 'Yolov5_DeepSort_Pytorch'...
# remote: Enumerating objects: 1092, done.
# remote: Total 1092 (delta 0), reused 0 (delta 0), pack-reused 1092
# Receiving objects: 100% (1092/1092), 25.73 MiB | 13.44 MiB/s, done.
# Resolving deltas: 100% (542/542), done.

# %%
# %pip install -qr Yolov5_DeepSort_Pytorch/requirements.txt  # install dependencies

# %%
import torch
print('Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Using torch 2.2.1+cu121 CPU

# %%
# !python yolov5/detect.py --weights yolov5m.pt  --img 640  --source /content/drive/MyDrive/DataScience/ComputerVision/pedestrian.mp4  --save-txt --class 0
# Out:
# detect: weights=['yolov5m.pt'], source=/content/drive/MyDrive/DataScience/ComputerVision/pedestrian.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=[0], agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-306-gb599ae42 Python-3.10.12 torch-2.2.1+cu121 CPU
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 21172173 parameters, 0 gradients, 48.9 GFLOPs
# video 1/1 (1/967) /content/drive/MyDrive/DataScience/ComputerVision/pedestrian.mp4: 480x640 (no detections), 937.1ms
# video 1/1 (2/967) /content/drive/MyDrive/DataScience/ComputerVision/pedestrian.mp4: 480x640 (no detections), 1277.7ms
# ...
